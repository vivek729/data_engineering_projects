# %% [markdown]
# # Test on local machine

# %%
import configparser
import datetime as dt
import os
import pyspark.sql.functions as F
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import (year, month, dayofmonth, hour,
                                   weekofyear, dayofweek, date_format)
from pyspark.sql.types import TimestampType, DateType

# %%
config = configparser.ConfigParser()
config.read('dl.cfg')

os.environ['AWS_ACCESS_KEY_ID'] = config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY'] = config['AWS']['AWS_SECRET_ACCESS_KEY']

# %% [markdown]
# ## Create Spark Session

# %%
spark = (
    SparkSession.builder
                .appName("sparkify")
                .config(
                    "spark.jars.packages",
                    "org.apache.hadoop:hadoop-aws:3.2.0"
                )
                .getOrCreate()
)
# spark = (
#     SparkSession.builder
#                 .getOrCreate()
# )

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://kumarv2-MOBL1.gar.corp.intel.com:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>sparkify</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
input_data = "s3a://udacity-dend/"
output_data = "s3a://sbucket62/sparkify/"

# %% [markdown]
# ## Process song data

# %%
song_data = os.path.join(input_data, "song_data/A/A/[AB]/*.json") # using a small subset of data
song_data
# Out:
# 's3a://udacity-dend/song_data/A/A/[AB]/*.json'

# %% [markdown]
# ### Read song data files

# %%
song_data_df = spark.read.json(song_data)

# %%
song_data_df.limit(5).toPandas()
# Out:
#             artist_id  artist_latitude                    artist_location  \
# 0  ARTC1LV1187B9A4858         51.45360  Goldsmith's College, Lewisham, Lo
# 1  ARA23XO1187B9AF18F         40.57885               Carteret, New Jersey
# 2  ARSVTNL1187B992A91         51.50632                    London, England
# 3  ARKIQCZ1187B9A7C7C         52.23974  Northampton, Northamptonshire, En
# 4  AR73AIO1187B9AD57B         37.77916                  San Francisco, CA
#
#    artist_longitude         artist_name   duration  num_songs  \
# 0          -0.01802  The Bonzo Dog Band  301.40036          1
# 1         -74.21956     The Smithereens  192.52200          1
# 2          -0.12714       Jonathan King  129.85424          1
# 3          -0.88576             Bauhaus  248.65914          1
# 4        -122.42005   Western Addiction  118.07302          1
#
#               song_id                                              title  year
# 0  SOAFBCP12A8C13CC7D              King Of Scurf (2007 Digital Remaster)  1972
# 1  SOKTJDS12AF72A25E5  Drown In My Own Tears (24-Bit Digitally Remast...     0
# 2  SOEKAZG12AB018837E      I'll Slap Your Face (Entertainment USA Theme)  2001
# 3  SOSIJKW12A8C1330E3               A God In An Alcove (Session Version)     0
# 4  SOQPWCR12A6D4FB2A3                   A Poor Recipe For Civic Cohesion  2005

# %%
song_data_df.count()
# Out:
# 50

# %%
song_data_df.printSchema()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: double (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)

# %% [markdown]
# ### Extract columns to create songs table

# %%
songs_table_df = song_data_df.select("song_id", "title", "artist_id", "year", "duration")
songs_table_df.limit(5).toPandas()
# Out:
#               song_id                                              title  \
# 0  SOAFBCP12A8C13CC7D              King Of Scurf (2007 Digital Remaster)
# 1  SOKTJDS12AF72A25E5  Drown In My Own Tears (24-Bit Digitally Remast...
# 2  SOEKAZG12AB018837E      I'll Slap Your Face (Entertainment USA Theme)
# 3  SOSIJKW12A8C1330E3               A God In An Alcove (Session Version)
# 4  SOQPWCR12A6D4FB2A3                   A Poor Recipe For Civic Cohesion
#
#             artist_id  year   duration
# 0  ARTC1LV1187B9A4858  1972  301.40036
# 1  ARA23XO1187B9AF18F     0  192.52200
# 2  ARSVTNL1187B992A91  2001  129.85424
# 3  ARKIQCZ1187B9A7C7C     0  248.65914
# 4  AR73AIO1187B9AD57B  2005  118.07302

# %%
songs_table_df.printSchema()
# Out:
# root
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- artist_id: string (nullable = true)
#  |-- year: long (nullable = true)
#  |-- duration: double (nullable = true)

# %% [markdown]
# ### Write songs table to parquet files partitioned by year and artist

# %%
songs_output_path = os.path.join(output_data, "songs/songs_table.parquet")
songs_output_path
# Out:
# 's3a://sbucket62/sparkify/songs/songs_table.parquet'

# %%
songs_table_df.write.partitionBy("year", "artist_id").mode("overwrite").parquet(songs_output_path)

# %% [markdown]
# ### Extract columns to create artists table

# %%
artists_table_df = df.select("artist_id", "artist_name", "artist_location", "artist_latitude", "artist_longitude")
artists_table_df.limit(5).toPandas()
# Out:
#             artist_id         artist_name                    artist_location  \
# 0  ARTC1LV1187B9A4858  The Bonzo Dog Band  Goldsmith's College, Lewisham, Lo
# 1  ARA23XO1187B9AF18F     The Smithereens               Carteret, New Jersey
# 2  ARSVTNL1187B992A91       Jonathan King                    London, England
# 3  ARKIQCZ1187B9A7C7C             Bauhaus  Northampton, Northamptonshire, En
# 4  AR73AIO1187B9AD57B   Western Addiction                  San Francisco, CA
#
#    artist_latitude  artist_longitude
# 0         51.45360          -0.01802
# 1         40.57885         -74.21956
# 2         51.50632          -0.12714
# 3         52.23974          -0.88576
# 4         37.77916        -122.42005

# %%
artists_table_df.count()
# Out:
# 50

# %%
artists_table_df.printSchema()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_longitude: double (nullable = true)

# %%
artists_table_unique_df = artists_table_df.dropDuplicates()

# %%
artists_table_unique_df.count()
# Out:
# 50

# %%
artists_table_unique_df.printSchema()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_longitude: double (nullable = true)

# %% [markdown]
# ### Write artist table to parquet files

# %%
artists_output_path = os.path.join(output_data, "artists/artists_table.parquet")
artists_output_path
# Out:
# 's3a://sbucket62/sparkify/artists/artists_table.parquet'

# %%
artists_table_unique_df.write.mode("overwrite").parquet(artists_output_path)

# %% [markdown]
# ## Process log data

# %%
log_data = os.path.join(input_data, "log_data/*/*/*.json")
log_data
# Out:
# 's3a://udacity-dend/log_data/*/*/*.json'

# %% [markdown]
# ### Read log data files

# %%
logs_df = spark.read.json(log_data)
logs_df.limit(10).toPandas()
# Out:
#         artist        auth firstName gender  itemInSession  lastName  \
# 0     Harmonia   Logged In      Ryan      M              0     Smith
# 1  The Prodigy   Logged In      Ryan      M              1     Smith
# 2        Train   Logged In      Ryan      M              2     Smith
# 3         None   Logged In     Wyatt      M              0     Scott
# 4         None   Logged In    Austin      M              0   Rosales
# 5  Sony Wonder   Logged In    Samuel      M              0  Gonzalez
# 6         None   Logged In    Samuel      M              1  Gonzalez
# 7         None  Logged Out      None   None              0      None
# 8         None   Logged In     Tegan      F              1    Levine
# 9    Van Halen   Logged In     Tegan      F              2    Levine
#
#       length level                               location method      page  \
# 0  655.77751  free     San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 1  260.07465  free     San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 2  205.45261  free     San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 3        NaN  free              Eureka-Arcata-Fortuna, CA    GET      Home
# 4        NaN  free  New York-Newark-Jersey City, NY-NJ-PA    GET      Home
# 5  218.06975  free   Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 6        NaN  free   Houston-The Woodlands-Sugar Land, TX    GET     About
# 7        NaN  paid                                   None    PUT     Login
# 8        NaN  paid            Portland-South Portland, ME    GET      Home
# 9  289.38404  paid            Portland-South Portland, ME    PUT  NextSong
#
#    registration  sessionId                                            song  \
# 0  1.541017e+12        583                                   Sehr kosmisch
# 1  1.541017e+12        583                                 The Big Gundown
# 2  1.541017e+12        583                                        Marry Me
# 3  1.540872e+12        563                                            None
# 4  1.541060e+12        521                                            None
# 5  1.540493e+12        597                                       Blackbird
# 6  1.540493e+12        597                                            None
# 7           NaN        602                                            None
# 8  1.540794e+12        602                                            None
# 9  1.540794e+12        602  Best Of Both Worlds (Remastered Album Version)
#
#    status             ts                                          userAgent  \
# 0     200  1542241826796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1     200  1542242481796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2     200  1542242741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3     200  1542247071796  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....
# 4     200  1542252577796  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...
# 5     200  1542253449796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 6     200  1542253460796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 7     307  1542260074796                                               None
# 8     200  1542260277796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 9     200  1542260935796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     26
# 1     26
# 2     26
# 3      9
# 4     12
# 5     61
# 6     61
# 7
# 8     80
# 9     80

# %% [markdown]
# ### Filter by actions for song plays

# %%
logs_filtered_df = logs_df.where(logs_df.page == "NextSong")
logs_filtered_df.limit(5).toPandas()
# Out:
#         artist       auth firstName gender  itemInSession  lastName  \
# 0     Harmonia  Logged In      Ryan      M              0     Smith
# 1  The Prodigy  Logged In      Ryan      M              1     Smith
# 2        Train  Logged In      Ryan      M              2     Smith
# 3  Sony Wonder  Logged In    Samuel      M              0  Gonzalez
# 4    Van Halen  Logged In     Tegan      F              2    Levine
#
#       length level                              location method      page  \
# 0  655.77751  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 1  260.07465  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 2  205.45261  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 3  218.06975  free  Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 4  289.38404  paid           Portland-South Portland, ME    PUT  NextSong
#
#    registration  sessionId                                            song  \
# 0  1.541017e+12        583                                   Sehr kosmisch
# 1  1.541017e+12        583                                 The Big Gundown
# 2  1.541017e+12        583                                        Marry Me
# 3  1.540493e+12        597                                       Blackbird
# 4  1.540794e+12        602  Best Of Both Worlds (Remastered Album Version)
#
#    status             ts                                          userAgent  \
# 0     200  1542241826796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1     200  1542242481796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2     200  1542242741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3     200  1542253449796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1542260935796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     26
# 1     26
# 2     26
# 3     61
# 4     80

# %%
logs_filtered_df.count()
# Out:
# 6820

# %%
logs_filtered_df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)

# %% [markdown]
# ### Extract columns for users table

# %%
users_table_df = logs_filtered_df.selectExpr("userId AS user_id",
                                             "firstName AS first_name",
                                             "lastName AS last_name",
                                             "gender", 
                                             "level"
                                            )
users_table_df.limit(5).toPandas()
# Out:
#   user_id first_name last_name gender level
# 0      26       Ryan     Smith      M  free
# 1      26       Ryan     Smith      M  free
# 2      26       Ryan     Smith      M  free
# 3      61     Samuel  Gonzalez      M  free
# 4      80      Tegan    Levine      F  paid

# %%
users_table_df.count()
# Out:
# 6820

# %%
users_table_unique_df = users_table_df.dropDuplicates()
users_table_unique_df.limit(5).toPandas()
# Out:
#   user_id first_name last_name gender level
# 0      26       Ryan     Smith      M  free
# 1       7     Adelyn    Jordan      F  free
# 2      71     Ayleen      Wise      F  free
# 3      81     Sienna     Colon      F  free
# 4      87     Dustin       Lee      M  free

# %%
users_table_unique_df.count()
# Out:
# 104

# %%
users_table_unique_df.printSchema()
# Out:
# root
#  |-- user_id: string (nullable = true)
#  |-- first_name: string (nullable = true)
#  |-- last_name: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- level: string (nullable = true)

# %% [markdown]
# ### Write users table to parquet files

# %%
users_output_path = os.path.join(output_data, "users/users_table.parquet")
users_output_path
# Out:
# 's3a://sbucket62/sparkify/users/users_table.parquet'

# %%
users_table_unique_df.write.mode("overwrite").parquet(users_output_path)

# %% [markdown]
# ### Create timestamp column from original timestamp column

# %%
get_timestamp = udf(lambda x: dt.datetime.utcfromtimestamp(x / 1000), TimestampType())

# %%
logs_filtered_df = logs_filtered_df.withColumn("start_time", get_timestamp("ts"))
logs_filtered_df.limit(5).toPandas()
# Out:
#         artist       auth firstName gender  itemInSession  lastName  \
# 0     Harmonia  Logged In      Ryan      M              0     Smith
# 1  The Prodigy  Logged In      Ryan      M              1     Smith
# 2        Train  Logged In      Ryan      M              2     Smith
# 3  Sony Wonder  Logged In    Samuel      M              0  Gonzalez
# 4    Van Halen  Logged In     Tegan      F              2    Levine
#
#       length level                              location method      page  \
# 0  655.77751  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 1  260.07465  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 2  205.45261  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 3  218.06975  free  Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 4  289.38404  paid           Portland-South Portland, ME    PUT  NextSong
#
#    registration  sessionId                                            song  \
# 0  1.541017e+12        583                                   Sehr kosmisch
# 1  1.541017e+12        583                                 The Big Gundown
# 2  1.541017e+12        583                                        Marry Me
# 3  1.540493e+12        597                                       Blackbird
# 4  1.540794e+12        602  Best Of Both Worlds (Remastered Album Version)
#
#    status             ts                                          userAgent  \
# 0     200  1542241826796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1     200  1542242481796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2     200  1542242741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3     200  1542253449796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1542260935796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId              start_time
# 0     26 2018-11-15 00:30:26.796
# 1     26 2018-11-15 00:41:21.796
# 2     26 2018-11-15 00:45:41.796
# 3     61 2018-11-15 03:44:09.796
# 4     80 2018-11-15 05:48:55.796

# %%
logs_filtered_df.printSchema()
# Out:
# root
#  |-- artist: string (nullable = true)
#  |-- auth: string (nullable = true)
#  |-- firstName: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- itemInSession: long (nullable = true)
#  |-- lastName: string (nullable = true)
#  |-- length: double (nullable = true)
#  |-- level: string (nullable = true)
#  |-- location: string (nullable = true)
#  |-- method: string (nullable = true)
#  |-- page: string (nullable = true)
#  |-- registration: double (nullable = true)
#  |-- sessionId: long (nullable = true)
#  |-- song: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- ts: long (nullable = true)
#  |-- userAgent: string (nullable = true)
#  |-- userId: string (nullable = true)
#  |-- start_time: timestamp (nullable = true)

# %% [markdown]
# ### Extract columns to create time table

# %%
time_table_df = logs_filtered_df.select("start_time")
time_table_df.count()
# Out:
# 6820

# %%
time_table_unique_df = time_table_df.dropDuplicates()
time_table_unique_df.count()
# Out:
# 6813

# %%
time_table_final_df = time_table_unique_df.select("start_time",
                                                  hour("start_time").alias("hour"),
                                                  dayofmonth("start_time").alias("day"),
                                                  weekofyear("start_time").alias("week"),
                                                  month("start_time").alias("month"),
                                                  year("start_time").alias("year"),
                                                  dayofweek("start_time").alias("weekday")
                                                  )
time_table_final_df.limit(5).toPandas()
# Out:
#                start_time  hour  day  week  month  year  weekday
# 0 2018-11-15 20:49:56.796    20   15    46     11  2018        5
# 1 2018-11-21 04:57:02.796     4   21    47     11  2018        4
# 2 2018-11-21 09:57:27.796     9   21    47     11  2018        4
# 3 2018-11-14 11:57:20.796    11   14    46     11  2018        4
# 4 2018-11-28 23:31:19.796    23   28    48     11  2018        4

# %%
time_table_final_df.printSchema()
# Out:
# root
#  |-- start_time: timestamp (nullable = true)
#  |-- hour: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- week: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- weekday: integer (nullable = true)

# %% [markdown]
# ### Write time table to parquet files partioned by year and month

# %%
time_output_path = os.path.join(output_data, "time/time_table.parquet")
time_output_path
# Out:
# 's3a://sbucket62/sparkify/time/time_table.parquet'

# %%
# write just 50 rows to check
time_table_final_df.limit(50).write.partitionBy("year", "month").mode("overwrite").parquet(time_output_path)

# %% [markdown]
# ### Create songplays table by joining `logs_filtered_df` and `song_data_df`

# %%
logs_filtered_df.createOrReplaceTempView("logs_filtered_table")
song_data_df.createOrReplaceTempView("song_data_table")

# %%
songplays_table_df = spark.sql("""
    SELECT
        row_number() OVER(ORDER BY start_time) AS songplay_id,
        l.start_time,
        l.userId AS user_id,
        l.level,
        s.song_id,
        s.artist_id,
        l.sessionId AS session_id,
        s.artist_location,
        l.userAgent AS user_agent
    FROM logs_filtered_table AS l
    LEFT OUTER JOIN song_data_table AS s ON
        (l.song = s.title)
        AND (l.artist = s.artist_name)
        AND (l.length = s.duration)
""")

# %%
songplays_table_df.limit(20).toPandas()
# Out:
#     songplay_id              start_time user_id level song_id artist_id  \
# 0             1 2018-11-01 21:01:46.796       8  free    None      None
# 1             2 2018-11-01 21:05:52.796       8  free    None      None
# 2             3 2018-11-01 21:08:16.796       8  free    None      None
# 3             4 2018-11-01 21:11:13.796       8  free    None      None
# 4             5 2018-11-01 21:17:33.796       8  free    None      None
# 5             6 2018-11-01 21:24:53.796       8  free    None      None
# 6             7 2018-11-01 21:28:54.796       8  free    None      None
# 7             8 2018-11-01 21:42:00.796      10  free    None      None
# 8             9 2018-11-01 21:52:05.796      26  free    None      None
# 9            10 2018-11-01 21:55:25.796      26  free    None      None
# 10           11 2018-11-01 22:23:14.796     101  free    None      None
# 11           12 2018-11-02 01:25:34.796     101  free    None      None
# 12           13 2018-11-02 01:30:41.796      83  free    None      None
# 13           14 2018-11-02 01:34:17.796      83  free    None      None
# 14           15 2018-11-02 02:42:48.796      66  free    None      None
# 15           16 2018-11-02 03:05:57.796      48  free    None      None
# 16           17 2018-11-02 03:34:34.796      86  free    None      None
# 17           18 2018-11-02 05:15:41.796      17  free    None      None
# 18           19 2018-11-02 05:52:29.796      66  free    None      None
# 19           20 2018-11-02 09:01:21.796      15  paid    None      None
#
#     session_id artist_location  \
# 0          139            None
# 1          139            None
# 2          139            None
# 3          139            None
# 4          139            None
# 5          139            None
# 6          139            None
# 7            9            None
# 8          169            None
# 9          169            None
# 10         100            None
# 11         184            None
# 12          82            None
# 13          82            None
# 14         153            None
# 15          47            None
# 16         170            None
# 17         118            None
# 18         187            None
# 19         172            None
#
#                                            user_agent
# 0   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 5   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 6   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 7   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 8   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 9   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 10  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 11  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 12  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 13  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 14  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 15  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 16  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 17  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 18  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 19  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...

# %%
songplays_table_df.count()
# Out:
# 6820

# %% [markdown]
# ### Write songplays table to parquet files partitioned by year and month

# %%
songplays_table_df = songplays_table_df.withColumn("year", year("start_time")) \
                                       .withColumn("month", month("start_time"))
songplays_table_df.limit(10).toPandas()
# Out:
#    songplay_id              start_time user_id level song_id artist_id  \
# 0            1 2018-11-01 21:01:46.796       8  free    None      None
# 1            2 2018-11-01 21:05:52.796       8  free    None      None
# 2            3 2018-11-01 21:08:16.796       8  free    None      None
# 3            4 2018-11-01 21:11:13.796       8  free    None      None
# 4            5 2018-11-01 21:17:33.796       8  free    None      None
# 5            6 2018-11-01 21:24:53.796       8  free    None      None
# 6            7 2018-11-01 21:28:54.796       8  free    None      None
# 7            8 2018-11-01 21:42:00.796      10  free    None      None
# 8            9 2018-11-01 21:52:05.796      26  free    None      None
# 9           10 2018-11-01 21:55:25.796      26  free    None      None
#
#    session_id artist_location  \
# 0         139            None
# 1         139            None
# 2         139            None
# 3         139            None
# 4         139            None
# 5         139            None
# 6         139            None
# 7           9            None
# 8         169            None
# 9         169            None
#
#                                           user_agent  year  month
# 0  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  2018     11
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  2018     11
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  2018     11
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  2018     11
# 4  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  2018     11
# 5  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  2018     11
# 6  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...  2018     11
# 7  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11
# 8  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...  2018     11
# 9  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...  2018     11

# %%
songplays_output_path = os.path.join(output_data, "songplays/songplays_table.parquet")
songplays_output_path
# Out:
# 's3a://sbucket62/sparkify/songplays/songplays_table.parquet'

# %%
# write just few rows to check
songplays_table_df.limit(20).write.partitionBy("year", "month").mode("overwrite").parquet(songplays_output_path)
